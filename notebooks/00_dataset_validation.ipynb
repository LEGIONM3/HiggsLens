# %% [markdown]
# # HiggsLens: CERN Dataset Validation & Inspection
#
# This notebook demonstrates loading the official ATLAS Higgs Challenge 2014 dataset (`atlas-higgs-challenge-2014-v2.csv.gz`), inspecting column definitions, checking `-999.0` sentinel distributions across jet multiplicities (`PRI_jet_num`), and verifying partition integrity.

# %%
import os

import pandas as pd

DATA_PATH = "../data/raw/atlas-higgs-challenge-2014-v2.csv.gz"
if os.path.exists(DATA_PATH):
    df = pd.read_csv(DATA_PATH)
    print(f"Loaded {len(df)} rows and {df.shape[1]} columns.")
    print(df['KaggleSet'].value_counts())
else:
    print("Dataset not found. Run `python scripts/download_dataset.py` first.")
