# %% [markdown]
# # HiggsLens: Baseline Multi-Model Experiments
#
# This notebook demonstrates baseline model experimentation across `dummy_prior`, `logistic_regression`, `random_forest`, and `histogram_gradient_boosting` using the `all_physics` feature set, and computing validation Approximate Median Significance (AMS) across decision thresholds.

# %%
import sys

sys.path.append("..")
from backend.app.models.registry import model_registry

print("Available candidate models in registry:")
for m_id, m_info in model_registry.list_models().items():
    print(f" - {m_info['display_name']} [{m_info['status']}]")
